# %%
# Out:
# 0.4499996144569838
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas_datareader\yahoo\options.py:666, in Options.expiry_dates(self)
#     665 try:
# --> 666     expiry_dates = self._expiry_dates
#     667 except AttributeError:
#
# AttributeError: 'Options' object has no attribute '_expiry_dates'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# Cell In[4], line 50
#      47 print(iv)
#      49 tsla = web.YahooOptions('TSLA')
# ---> 50 calls = tsla.get_call_data()
#      52 calls.reset_index(inplace=True)
#      53 calls['mid'] = (calls.Bid + calls.Ask)/2
#
# ...
